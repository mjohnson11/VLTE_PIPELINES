# %%
from PIL import Image, ImageEnhance, ImageDraw, ImageFont
from glob import glob
import pandas as pd
import numpy as np

# %%
file_info = pd.read_csv('../Data/Imaging/Image_files_to_wells_2_7_20.csv')
file_info['platewell'] = file_info['Plate'] + '_' + file_info['Well']
file_info.iloc[:3]
# Out:
#                            File Focal_plate_well              ID  Plate  \
# 0  B1_2_7_20/B1_2_7_20_s001.tif    P3_Foc_B1_A01  Blank_Blank_G0  Blank
# 1  B1_2_7_20/B1_2_7_20_s002.tif    P4_G10150_A01   P4_A01_G10150     P4
# 2  B1_2_7_20/B1_2_7_20_s003.tif    P3_Foc_B1_A02    P3_C05_G1410     P3
#
#     Well  Generation    platewell
# 0  Blank           0  Blank_Blank
# 1    A01       10150       P4_A01
# 2    C05        1410       P3_C05

# %%
wells_w_6_tps[wells_w_6_tps['platewell']=='P3_B10']
# Out:
#                                                   File Focal_plate_well  \
# 699  Combination_plate_2_7_20/Combination_plate_s28...    P3_Foc_B1_H11
# 707  Combination_plate_2_7_20/Combination_plate_s36...    P3_Foc_B1_H07
# 715  Combination_plate_2_7_20/Combination_plate_s44...    P3_Foc_B1_H03
# 747  Combination_plate_2_7_20/Combination_plate_s76...    P3_Foc_B2_H11
# 755  Combination_plate_2_7_20/Combination_plate_s84...    P3_Foc_B2_H07
# 763  Combination_plate_2_7_20/Combination_plate_s92...    P3_Foc_B2_H03
#
#                 ID Plate Well  Generation platewell
# 699  P3_B10_G10150    P3  B10       10150    P3_B10
# 707   P3_B10_G5150    P3  B10        5150    P3_B10
# 715   P3_B10_G1410    P3  B10        1410    P3_B10
# 747   P3_B10_G7530    P3  B10        7530    P3_B10
# 755   P3_B10_G2640    P3  B10        2640    P3_B10
# 763     P3_B10_G70    P3  B10          70    P3_B10

# %%
gens = [70, 1410, 2640, 5150, 7530, 10150]
wells_w_6_tps = file_info[file_info['Plate'].isin(['P1', 'P2', 'P3'])]
crop_buf = 50
crop_x = 1200
crop_y = 930
buf = 20
bw = int((crop_x-crop_buf)*3+buf*7)
bh = int((crop_y-crop_buf)/2+80)
myfont = ImageFont.truetype('accessory_files/Avenir.ttc', 40)
for pw in [i for i in list(set(wells_w_6_tps['platewell'])) if i=='P3_B10']:
    print(pw)
    td = wells_w_6_tps[wells_w_6_tps['platewell']==pw]
    background = Image.new('RGBA',(bw, bh), (255, 255, 255, 255))
    draw = ImageDraw.Draw(background)
    for g in range(len(gens)):
        gen = gens[g]
        ttd = td[td['Generation']==gen]
        assert(len(ttd)==1)
        offset = (int(buf+g*((bw-buf)/6)), 60)
        im = ImageEnhance.Contrast(Image.open('../Data/Imaging/2_7_20/'+ttd.iloc[0]['File'])).enhance(3)
        background.paste(im.crop((crop_buf, crop_buf, crop_x, crop_y)).resize((int((crop_x-crop_buf)/2), int((crop_y-crop_buf)/2))),offset)
        draw.text((offset[0]+20, 10),pw.replace('_', '') + ' Gen. ' + str(gen), (0,0,0),font=myfont)
    background.save('../Output/Figs/supp_figs/imaging/cropped_'+pw.replace('_', '')+'.png')
# Out:
# P3_B10
